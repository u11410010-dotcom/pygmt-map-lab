# %% [markdown]
# <a href="https://colab.research.google.com/github/u11410010-dotcom/pygmt-map-lab/blob/main/H2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import importlib.util
import subprocess
import sys

# 在子程序檢查，避免安裝前先載入目前 kernel 的動態函式庫
check_code = """
import pygmt, pandas
import shutil
from pygmt.clib import Session
assert pygmt.__version__.lstrip('v').startswith('0.17.')
assert shutil.which('gs')
with Session() as session:
    assert session.info['version'].startswith('6.5.')
"""
try:
    ENV_READY = subprocess.run(
        [sys.executable, "-c", check_code], capture_output=True, timeout=30
    ).returncode == 0
except subprocess.TimeoutExpired:
    ENV_READY = False

IN_COLAB = importlib.util.find_spec("google.colab") is not None if importlib.util.find_spec("google") else False
if ENV_READY:
    print("環境已可用，跳過安裝。")
elif IN_COLAB:
    print("步驟 1/2：安裝 Conda（約 1 分鐘）。完成後 Colab 會自動重啟執行環境，等重新連線再執行下一格。", flush=True)
    subprocess.check_call([sys.executable, "-m", "pip", "install", "-q", "condacolab==0.1.13"])
    import condacolab
    condacolab.install()
else:
    print("本機模式：使用目前 Python 環境。")
# Out:
# 步驟 1/2：安裝 Conda（約 1 分鐘）。完成後 Colab 會自動重啟執行環境，等重新連線再執行下一格。
#
# 📢 Announcement 📢
# condacolab==0.2 will be released soon! Try it with:
#
#     !pip install -q https://github.com/conda-incubator/condacolab/archive/main.zip
#     import condacolab
#     condacolab.install()
#
# 0.2.x introduces a new installation method based on Pixi, with customizable Python versions.
# This may be breaking for your workflow. If that's the case, please report it at
# https://github.com/conda-incubator/condacolab and pin your `pip install` command to
# condacolab==0.1 as a workaround.
#
# ✨🍰✨ Everything looks OK!

# %%
import importlib.util
import subprocess
import sys

# 在子程序檢查，避免安裝前先載入目前 kernel 的動態函式庫
check_code = """
import pygmt, pandas
import shutil
from pygmt.clib import Session
assert pygmt.__version__.lstrip('v').startswith('0.17.')
assert shutil.which('gs')
with Session() as session:
    assert session.info['version'].startswith('6.5.')
"""
try:
    ENV_READY = subprocess.run(
        [sys.executable, "-c", check_code], capture_output=True, timeout=30
    ).returncode == 0
except subprocess.TimeoutExpired:
    ENV_READY = False

IN_COLAB = importlib.util.find_spec("google.colab") is not None if importlib.util.find_spec("google") else False
if ENV_READY:
    print("環境已可用，跳過安裝。")
elif IN_COLAB:
    print("步驟 2/2：安裝 PyGMT 與相依套件（約 2–4 分鐘），下方會逐行顯示進度。", flush=True)
    command = ["mamba", "install", "-y", "-c", "conda-forge", "pygmt=0.17", "gmt=6.5", "ghostscript=10.04", "pandas"]
    with subprocess.Popen(command, stdout=subprocess.PIPE, stderr=subprocess.STDOUT, text=True, bufsize=1) as process:
        for line in process.stdout:
            print(line.rstrip(), flush=True)
    if process.returncode != 0:
        raise RuntimeError(f"安裝失敗（exit {process.returncode}），請重新執行本格或重啟執行環境。")
    print("安裝完成，可以往下執行。")
else:
    print("跳過 Colab 安裝。")
# Out:
# 步驟 2/2：安裝 PyGMT 與相依套件（約 2–4 分鐘），下方會逐行顯示進度。
#
# Pinned packages:
#
#   - python=3.13
#
# Pinned packages:
#
#   - python_abi[version="=3.13",build="*cp313*"]
#
# Pinned packages:
#
#   - cuda-version*.*
#
# Pinned packages:
#
#   - python=3.13
#
#
# Transaction
#
#   Prefix: /usr/local
#
#   Updating specs:
#
#    - pygmt=0.17
#    - gmt=6.5
#    - ghostscript=10.4
#    - pandas
#
#
#   Package                    Version  Build                 Channel           Size
# ────────────────────────────────────────────────────────────────────────────────────
#   Install:
# ────────────────────────────────────────────────────────────────────────────────────
#
#   + blosc                     1.21.6  he440d0b_1            conda-forge       48kB
#   + curl                      8.20.0  hcf29cc6_0            conda-forge      191kB
#   + dcw-gmt                    2.2.0  ha770c72_0            conda-forge       22MB
#   + fftw                      3.3.11  nompi_h3b011a4_100    conda-forge        2MB
#   + freexl                     2.0.0  h1f12c17_3            conda-forge       62kB
#   + geos                      3.13.1  h97f6797_0            conda-forge        2MB
#   + ghostscript              10.04.0  h5888daf_0            conda-forge       61MB
#   + giflib                     5.2.2  ha257d8a_1            conda-forge       77kB
#   + gmt                        6.5.0  hf220daf_10           conda-forge       34MB
#   + gshhg-gmt                  2.3.7  ha770c72_1003         conda-forge       57MB
#   + hdf4                      4.2.15  h2a13503_7            conda-forge      757kB
#   + hdf5                      1.14.6  nompi_h19486de_110    conda-forge        4MB
#   + json-c                      0.18  h6688a6e_0            conda-forge       83kB
#   + lerc                       4.2.0  hdb68285_0            conda-forge      271kB
#   + libaec                     1.1.5  h088129d_0            conda-forge       37kB
#   + libblas                   3.11.0  11_h4a7cf45_openblas  conda-forge       18kB
#   + libbrotlicommon            1.2.0  hb03c661_1            conda-forge       80kB
#   + libbrotlidec               1.2.0  hb03c661_1            conda-forge       35kB
#   + libbrotlienc               1.2.0  hb03c661_1            conda-forge      298kB
#   + libcblas                  3.11.0  11_h0358290_openblas  conda-forge       18kB
#   + libdeflate                  1.25  hd45a770_1            conda-forge       74kB
#   + libgdal-core              3.11.3  ha8f0914_2            conda-forge       12MB
#   + libgdal-jp2openjpeg       3.11.3  hdd07572_2            conda-forge      473kB
#   + libgfortran               15.2.0  h69a702a_20           conda-forge       28kB
#   + libgfortran5              15.2.0  h68bc16d_20           conda-forge        2MB
#   + libglib                   2.84.3  hf39c6af_0            conda-forge        4MB
#   + libhwy                     1.4.0  h57c4cff_1            conda-forge        1MB
#   + libjpeg-turbo              3.2.0  hb03c661_1            conda-forge      650kB
#   + libjxl                    0.11.2  h174a0a3_1            conda-forge        2MB
#   + libkml                     1.3.0  haa4a5bd_1023         conda-forge      413kB
#   + liblapack                 3.11.0  11_h47877c9_openblas  conda-forge       18kB
#   + libnetcdf                  4.9.2  nompi_h21f7587_118    conda-forge      844kB
#   + libnsl                     2.0.1  hb9d3cd8_1            conda-forge       34kB
#   + libopenblas               0.3.34  pthreads_h94d23a6_0   conda-forge        6MB
#   + libpng                    1.6.58  h922cc85_1            conda-forge      317kB
#   + librttopo                  1.1.0  hd718a1a_18           conda-forge      233kB
#   + libspatialite              5.1.0  he17ca71_14           conda-forge        4MB
#   + libstdcxx-ng              15.2.0  hdf11a46_19           conda-forge       28kB
#   + libtiff                    4.7.2  hcc2c06a_1            conda-forge      460kB
#   + libwebp-base               1.6.0  hd42ef1d_1            conda-forge      428kB
#   + libzip                    1.11.4  h6008cf6_0            conda-forge      113kB
#   + minizip                    4.2.2  haac24f3_1            conda-forge      567kB
#   + muparser                   2.3.5  hee9eb32_1            conda-forge      233kB
#   + numpy                      2.5.3  py313hb5f73ae_0       conda-forge        9MB
#   + openjpeg                   2.5.4  heb1ab33_2            conda-forge      391kB
#   + pandas                     3.0.6  np2py313h4900a6c_0    conda-forge       15MB
#   + pcre                        8.45  h9c3ff4c_0            conda-forge      259kB
#   + pcre2                      10.45  hc749103_0            conda-forge        1MB
#   + proj                       9.6.2  h18fbb6c_2            conda-forge        3MB
#   + pygmt                     0.17.0  pyhcf101f3_0          conda-forge      198kB
#   + python-dateutil      2.9.0.post0  pyhe01879c_2          conda-forge      233kB
#   + six                       1.17.0  pyhe01879c_1          conda-forge       18kB
#   + snappy                     1.2.2  h34e00bb_2            conda-forge       46kB
#   + sqlite                    3.53.1  hbc0de68_0            conda-forge      205kB
#   + uriparser                  0.9.8  hac33072_0            conda-forge       48kB
#   + xarray                  2026.7.0  pyhc364b38_0          conda-forge        1MB
#   + xerces-c                   3.2.5  h988505b_2            conda-forge        2MB
#   + zlib                       1.3.2  h25fd6f3_2            conda-forge       96kB
#
#   Remove:
# ────────────────────────────────────────────────────────────────────────────────────
#
#   - libmamba-spdlog            2.5.0  h12fcf84_0            conda-forge     Cached
#   - libxml2-16                2.15.3  hca6bf5a_0            conda-forge     Cached
#
#   Change:
# ────────────────────────────────────────────────────────────────────────────────────
#
#   - cffi                       2.0.0  py313hf46b229_1       conda-forge     Cached
#   + cffi                       2.0.0  py313hf01b4d8_0       conda-forge      298kB
#
#   Downgrade:
# ────────────────────────────────────────────────────────────────────────────────────
#
#   - fmt                       12.1.0  hff5e90c_0            conda-forge     Cached
#   + fmt                       11.2.0  h07f6e7f_0            conda-forge      193kB
#   - icu                         78.3  h33c6efd_0            conda-forge     Cached
#   + icu                         75.1  he02047a_0            conda-forge       12MB
#   - libarchive                 3.8.7  gpl_hc2c16d8_101      conda-forge     Cached
#   + libarchive                 3.8.1  gpl_h98cc613_100      conda-forge      883kB
#   - libffi                     3.5.2  h3435931_0            conda-forge     Cached
#   + libffi                     3.4.6  h2dba641_1            conda-forge       57kB
#   - libmamba                   2.5.0  hd28c85e_0            conda-forge     Cached
#   + libmamba                   2.3.2  hae34dd5_2            conda-forge        2MB
#   - libmambapy                 2.5.0  py313h4616538_0       conda-forge     Cached
#   + libmambapy                 2.3.2  py313h2dcffc8_2       conda-forge      771kB
#   - libxml2                   2.15.3  h49c6c72_0            conda-forge     Cached
#   + libxml2                   2.13.9  h04c0eec_0            conda-forge      697kB
#   - mamba                      2.5.0  h9835478_0            conda-forge     Cached
#   + mamba                      2.3.2  h4a52834_2            conda-forge      528kB
#   - pybind11-abi                  11  hc364b38_1            conda-forge     Cached
#   + pybind11-abi                   4  hd8ed1ab_3            conda-forge       10kB
#   - python                   3.13.13  h6add32d_100_cp313    conda-forge     Cached
#   + python                    3.13.9  h2b335a9_100_cp313    conda-forge       37MB
#   - simdjson                   4.2.4  hb700be7_0            conda-forge     Cached
#   + simdjson                   4.0.7  hb700be7_0            conda-forge      268kB
#   - spdlog                    1.17.0  hab81395_1            conda-forge     Cached
#   + spdlog                    1.16.0  ha91398d_0            conda-forge      198kB
#
#   Summary:
#
#   Install: 58 packages
#   Remove: 2 packages
#   Change: 1 packages
#   Downgrade: 12 packages
#
#   Total download: 310MB
#
# ────────────────────────────────────────────────────────────────────────────────────
#
#
#
# Transaction starting
# Unlinking libxml2-16-2.15.3-hca6bf5a_0
# Unlinking simdjson-4.2.4-hb700be7_0
# Unlinking fmt-12.1.0-hff5e90c_0
# Unlinking libffi-3.5.2-h3435931_0
# Unlinking icu-78.3-h33c6efd_0
# Unlinking libxml2-2.15.3-h49c6c72_0
# Unlinking libarchive-3.8.7-gpl_hc2c16d8_101
# Unlinking spdlog-1.17.0-hab81395_1
# Unlinking python-3.13.13-h6add32d_100_cp313
# Unlinking cffi-2.0.0-py313hf46b229_1
# Unlinking pybind11-abi-11-hc364b38_1
# Unlinking libmamba-spdlog-2.5.0-h12fcf84_0
# Unlinking libmamba-2.5.0-hd28c85e_0
# Unlinking libmambapy-2.5.0-py313h4616538_0
# Unlinking mamba-2.5.0-h9835478_0
# Linking ghostscript-10.04.0-h5888daf_0
# Linking geos-3.13.1-h97f6797_0
# Linking pcre2-10.45-hc749103_0
# Linking libstdcxx-ng-15.2.0-hdf11a46_19
# Linking simdjson-4.0.7-hb700be7_0
# Linking curl-8.20.0-hcf29cc6_0
# Linking fmt-11.2.0-h07f6e7f_0
# Linking zlib-1.3.2-h25fd6f3_2
# Linking libffi-3.4.6-h2dba641_1
# Linking libgfortran5-15.2.0-h68bc16d_20
# Linking dcw-gmt-2.2.0-ha770c72_0
# Linking libaec-1.1.5-h088129d_0
# Linking json-c-0.18-h6688a6e_0
# Linking gshhg-gmt-2.3.7-ha770c72_1003
# Linking snappy-1.2.2-h34e00bb_2
# Linking libzip-1.11.4-h6008cf6_0
# Linking giflib-5.2.2-ha257d8a_1
# Linking lerc-4.2.0-hdb68285_0
# Linking libdeflate-1.25-hd45a770_1
# Linking libjpeg-turbo-3.2.0-hb03c661_1
# Linking libbrotlicommon-1.2.0-hb03c661_1
# Linking libpng-1.6.58-h922cc85_1
# Linking libwebp-base-1.6.0-hd42ef1d_1
# Linking muparser-2.3.5-hee9eb32_1
# Linking libnsl-2.0.1-hb9d3cd8_1
# Linking sqlite-3.53.1-hbc0de68_0
# Linking libhwy-1.4.0-h57c4cff_1
# Linking minizip-4.2.2-haac24f3_1
# Linking librttopo-1.1.0-hd718a1a_18
# Linking uriparser-0.9.8-hac33072_0
# Linking pcre-8.45-h9c3ff4c_0
# Linking icu-75.1-he02047a_0
# Linking libxml2-2.13.9-h04c0eec_0
# Linking libarchive-3.8.1-gpl_h98cc613_100
# Linking spdlog-1.16.0-ha91398d_0
# Linking libglib-2.84.3-hf39c6af_0
# Linking python-3.13.9-h2b335a9_100_cp313
# Linking libgfortran-15.2.0-h69a702a_20
# Linking blosc-1.21.6-he440d0b_1
# Linking hdf4-4.2.15-h2a13503_7
# Linking libbrotlienc-1.2.0-hb03c661_1
# Linking libbrotlidec-1.2.0-hb03c661_1
# Linking libtiff-4.7.2-hcc2c06a_1
# Linking freexl-2.0.0-h1f12c17_3
# Linking libkml-1.3.0-haa4a5bd_1023
# Linking xerces-c-3.2.5-h988505b_2
# Linking cffi-2.0.0-py313hf01b4d8_0
# Linking hdf5-1.14.6-nompi_h19486de_110
# Linking fftw-3.3.11-nompi_h3b011a4_100
# Linking libopenblas-0.3.34-pthreads_h94d23a6_0
# Linking libjxl-0.11.2-h174a0a3_1
# Linking proj-9.6.2-h18fbb6c_2
# Linking openjpeg-2.5.4-heb1ab33_2
# Linking libnetcdf-4.9.2-nompi_h21f7587_118
# Linking libblas-3.11.0-11_h4a7cf45_openblas
# Linking libspatialite-5.1.0-he17ca71_14
# Linking libcblas-3.11.0-11_h0358290_openblas
# Linking liblapack-3.11.0-11_h47877c9_openblas
# Linking libgdal-core-3.11.3-ha8f0914_2
# Linking numpy-2.5.3-py313hb5f73ae_0
# warning  libmamba [numpy-2.5.3-py313hb5f73ae_0] The following files were already present in the environment:
#     - bin/f2py
#     - bin/numpy-config
# Linking libgdal-jp2openjpeg-3.11.3-hdd07572_2
# Linking gmt-6.5.0-hf220daf_10
# Linking pybind11-abi-4-hd8ed1ab_3
# Linking six-1.17.0-pyhe01879c_1
# Linking python-dateutil-2.9.0.post0-pyhe01879c_2
# Linking libmamba-2.3.2-hae34dd5_2
# Linking libmambapy-2.3.2-py313h2dcffc8_2
# Linking pandas-3.0.6-np2py313h4900a6c_0
# Linking mamba-2.3.2-h4a52834_2
# Linking xarray-2026.7.0-pyhc364b38_0
# Linking pygmt-0.17.0-pyhcf101f3_0
#
# Transaction finished
#
# 安裝完成，可以往下執行。

# %%
# !git clone https://github.com/u11410010-dotcom/pygmt-map-lab.git
# Out:
# fatal: destination path 'pygmt-map-lab' already exists and is not an empty directory.

# %%
# %run /content/pygmt-map-lab/examples/02_region_map_section.py
# Out:
# USGS 2000-01-01 起 M >= 5.0：2877 筆
# 走廊內 444 筆；A–B 長 1564 km
# grdblend [NOTICE]: Remote data courtesy of GMT data server oceania [http://oceania.generic-mapping-tools.org]
# grdblend [NOTICE]: SRTM15 Earth Relief v2.7 at 02x02 arc minutes reduced by Gaussian Cartesian filtering (10.5 km fullwidth) [Tozer et al., 2019].
# grdblend [NOTICE]:   -> Download 60x60 degree grid tile (earth_relief_02m_g): N30E120
# 圖說骨架：USGS 2000-01-01 起 M >= 5.0，範圍 [128, 150, 30, 46]，A=(130, 38.5)、B=(148, 38.5)，走廊全寬 200 km；剖面 VE = 1.3x；走廊內 21% 的深度是 USGS 預設值（10／33 km）。
# saved region_map.png region_section.png
